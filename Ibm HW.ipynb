# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Ayse Erdem- Master Student in the System Science and Industrial Engineering Departman**

# %% [markdown]
# *I am interested in Data science because it is an important field and it has many job opportunities.

# %% [markdown]
# ### I will show you how to do simple math in the next cell.

# %%
a = 1 
b = 4
a + b
# Out:
# 5

# %% [markdown]
# -  Tools
#     -  Python
#     -  Rstudio
#     -  Spss
# *****
# 1. Data Science
# 2. Data Engineering
# 3. Data Analytics
#
# ****
# [Hyperlink](https://stackoverflow.com/questions/25692293/inserting-a-link-to-a-webpage-in-an-ipython-notebook)
